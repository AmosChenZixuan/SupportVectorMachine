# %% [markdown]
# ## Demo for primal SVM using QP

# %%
import numpy as np
import matplotlib.pyplot as plt
from SVM_QP import SVM_QP as SVM

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Hard Margin SVM for linearly separable data

# %%
data = np.loadtxt('linear_data.txt',delimiter='    ')
x = data[:,:-1]
y = data[:,-1]
model = SVM()
sol = model.fit(x,y)
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  6.1605e-02  1.5512e+01  3e+02  2e+00  4e+02
#  1:  4.6923e-01 -2.4897e+01  3e+01  2e-01  5e+01
#  2:  5.6419e-01 -5.4449e-01  1e+00  4e-03  1e+00
#  3:  3.7597e-01  2.0897e-01  2e-01  4e-04  1e-01
#  4:  3.7242e-01  3.3507e-01  4e-02  2e-05  4e-03
#  5:  3.6927e-01  3.6477e-01  5e-03  2e-06  4e-04
#  6:  3.6875e-01  3.6871e-01  5e-05  2e-08  4e-06
#  7:  3.6875e-01  3.6875e-01  5e-07  2e-10  4e-08
#  8:  3.6875e-01  3.6875e-01  5e-09  2e-12  4e-10
# Optimal solution found.

# %%
model.error(x,y)
# Out:
# 0.0

# %%
model.plot(x,y,title='Hard')

# %% [markdown]
# ## Soft Margin Kernel SVM for non-linearly separable data

# %%
data = np.loadtxt('nonlinear_data.txt',delimiter='    ')
x = data[:,:-1]
y = data[:,-1]
model = SVM(kernel='poly')
sol = model.fit(x,y,1.0) # c = 0.5 for soft svm
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -3.9117e+01  1.8706e+02  8e+02  4e+00  5e+00
#  1:  1.3017e+02  1.4306e+01  1e+02  7e-02  1e-01
#  2:  4.0602e+01  2.5822e+01  2e+01  9e-03  1e-02
#  3:  3.4569e+01  3.0664e+01  4e+00  2e-03  3e-03
#  4:  3.3333e+01  3.2105e+01  1e+00  4e-04  6e-04
#  5:  3.2860e+01  3.2541e+01  3e-01  1e-04  2e-04
#  6:  3.2718e+01  3.2674e+01  4e-02  6e-06  9e-06
#  7:  3.2697e+01  3.2693e+01  4e-03  5e-07  7e-07
#  8:  3.2695e+01  3.2695e+01  8e-05  7e-09  1e-08
#  9:  3.2695e+01  3.2695e+01  4e-06  4e-10  6e-10
# Optimal solution found.

# %%
model.error(x,y)
# Out:
# 0.02

# %%
model.plot(x,y,title='Hard')
