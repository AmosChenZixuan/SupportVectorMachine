# %% [markdown]
# ## Demo for primal SVM using QP

# %%
import numpy as np
import matplotlib.pyplot as plt
from SVM_QP import SVM_QP as SVM

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Hard Margin SVM for linearly separable data

# %%
data = np.loadtxt('linear_data.txt',delimiter='    ')
x = data[:,:-1]
y = data[:,-1]
model = SVM()
sol = model.fit(x,y)

# %%
sol['iterations']
# Out:
# 8

# %%
model.error(x,y)
# Out:
# 0.0

# %%
model.plot(x,y,title='Hard')

# %% [markdown]
# ## Soft Margin Kernel SVM for non-linearly separable data

# %%
data = np.loadtxt('nonlinear_data.txt',delimiter='    ')
x = data[:,:-1]
y = data[:,-1]
model = SVM(kernel='rbf')
sol = model.fit(x,y,50.0) # c = 50 for soft svm

# %%
sol['iterations']
# Out:
# 10

# %%
model.error(x,y)
# Out:
# 0.0

# %%
model.plot(x,y,title='Hard')
